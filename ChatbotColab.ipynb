# %% [markdown]
# ### CSUSB Podcast Chat Bot

# %% [markdown]
# #  **🚀 Introduction**
# This project takes a PDF document (such as a research paper or textbook chapter), extracts its text, and generates a conversational-style podcast between two AI agents: Alpha and Beta. The AI models analyze the document and create a discussion based on its content.

# %% [markdown]
# #🛠️ **Prerequisites**
# No need to install libraries or configure your environment manually! Everything is handled by the Google Colab Python Engine Backend. The setup will also create a Colab Runtime by enabling you to run code cell-by-cell without any typing or copying.
#
# You will need a GROQ API key which can be obtianited at([GROQ API](https://console.groq.com/keys))

# %% [markdown]
# #🤔 How It Works
# The chatbot relies on:
#
# LLMs (Large Language Models): Generate human respones to prompts
#
# *   LLMs (Large Language Models): Generate human respones to prompts
# *   PDF Extractor (PyPDF2): Extracts Text from PDF to use as refrecnce for podcast.

# %% [markdown]
# # Chatbot Flowchart Diagram
# ![CSE6550 (1).png](data:image/png;base64,...)

# %% [markdown]
# # ⚙️ Running the Chatbot
# To set up and run the chatbot:
#
# Click on Runtime
# Select "Run All Cells"
# Have your GROQ API Key ready

# %% [markdown]
# # 📚 Why Are Libraries Important?
# Python libraries provide premade tools so that everything is not made from scratch. This project uses several specialized libraries to:
#
# Manage database operations.
# Extract Text from PDF.
# Create Web Based UI
# Create chat prompts and interactions.

# %% [markdown]
# # **1. Project Requirements**
# Libraries Used
# The code requires the following Python libraries:
#
#
# * streamlit → For building the web-based UI
# *  speech_recognition → For voice-based interaction (optional)
# *   os → To handle environment variables
#
# *   pandas, numpy → For potential data processing
# *   langchain.chat_models → For initializing AI chat models
#
# *  langchain.schema → For structuring AI conversations
# *   PyPDF2 → For extracting text from uploaded PDF files
#
# *   time → To add natural pauses in the conversation

# %% [markdown]
# # **2. Project Overview**
# Workflow
#
# 1.User uploads a PDF file 📄
#
# 2.AI extracts text from the document 📖
#
# 3.Two AI agents (Alpha & Beta) generate a conversation 🗣️
#
# 4.The conversation is displayed in a podcast-style format 🎙️

# %% [markdown]
# (A) Installing Libraries

# %%
# !pip install pandas
# !pip install numpy
# !pip install langchain.core
# !pip install langchain_community
# !pip install langchain[groq]
# !pip install llama-index
# !pip install openai
# !pip install -U langchain-groq
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 1.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 418.7/418.7 kB 10.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 351.9/351.9 kB 19.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.8/132.8 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 77.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.2/69.2 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 37.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 58.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 42.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 80.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.9/274.9 kB 16.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# b) Import neccesary libaries

# %%
import os
import time
from langchain.chat_models import init_chat_model
from langchain.schema import SystemMessage, HumanMessage, AIMessage

# %% [markdown]
# c) Enter GROQ API key

# %%
apik = input("Please enter your GROQ API key: ").strip()
if not apik:
    raise ValueError("Error: API key cannot be empty.")
else:
    os.environ['GROQ_API_KEY'] = apik
# Out:
# Please enter your GROQ API key: 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

# %% [markdown]
# d) Using two llama3 models for alpha and beta

# %%
chat_alpha = init_chat_model("llama3-8b-8192", model_provider="groq")  # Alpha's model
chat_beta = init_chat_model("llama3-70b-8192", model_provider="groq")  # Beta's model

messages = [SystemMessage(content="You are an AI assistant that will help.")]

# %% [markdown]
# e) Asking question to chatbot

# %%
user_input = input("Ask the Chatbot a Question: ")

if user_input:
    prompt = f"User Query: {user_input}"

    response = chat_alpha.invoke([SystemMessage(content=prompt)])
    ai_response = response.content if response else "I do not know!"

    print(f"Alpha: {user_input}")
    print(f"Beta: {ai_response}")
# Out:
# Ask the Chatbot a Question: what is CSUSB?
# Alpha: what is CSUSB?
# Beta: CSUSB stands for California State University, San Bernardino. It is a public university located in San Bernardino, California, United States. CSUSB is part of the California State University (CSU) system, which is one of the largest and most comprehensive public university systems in the United States.
#
# CSUSB offers a wide range of undergraduate and graduate degree programs in fields such as business, education, engineering, health sciences, humanities, natural sciences, and social sciences. The university is known for its strong programs in areas such as entrepreneurship, sustainability, and community engagement.
#
# CSUSB has a diverse student body of around 20,000 students, with a mix of undergraduate and graduate students. The university has a strong commitment to student success, with a variety of support services and programs designed to help students achieve their academic and career goals.
#
# ...

# %% [markdown]
# f) Conversation between alpha and beta regarding csusb (aipodcast)

# %%
def start_aipodcast():
    for _ in range(10):  # 10 questions session
        # Alpha asks a question about CSUSB
        question_prompt = "Generate a short, clear, and direct question (1-3 lines) about CSUSB's podcast, events, admissions, or campus life."

        messages.append(HumanMessage(content=question_prompt))
        question_response = chat_alpha.invoke(messages)
        question = question_response.content.strip() if question_response else "Could not generate a question."

        print(f"Alpha: {question}")
        time.sleep(1)

#Beta answers in 3-4 lines summary format
        beta_prompt = f"Provide a concise 3-4 line summary answering the following question: {question}"
        response = chat_beta.invoke([SystemMessage(content=beta_prompt)])
        ai_response = response.content.strip() if response else "I don't know"

        messages.append(AIMessage(content=ai_response))
        print(f"Beta: {ai_response}")
        print("-" * 50)
        time.sleep(1)

#Start AI Podcast
start_aipodcast()
# Out:
# Alpha: Here's a question:
#
# What are the most popular events and activities on the CSUSB campus that are open to all students, and how can I stay updated on upcoming events?
# Beta: The most popular events and activities on the CSUSB campus that are open to all students include concerts, cultural festivals, guest lectures, and outdoor recreation activities. Students can stay updated on upcoming events through the university's event calendar, social media, and the CSUSB mobile app. Additionally, students can sign up for the weekly "What's Happening @ CSUSB" email newsletter to receive updates on campus events and activities.
# --------------------------------------------------
# Alpha: What types of student organizations and clubs are available on the CSUSB campus, and how can I get involved with them?
# ...
