# %% [markdown]
# # **CSUSB Podcast Chat Bot**

# %% [markdown]
# #  **🚀 Introduction**
# CSUSB Study Podcast Assistant, an AI-powered tool designed to transform PDF documents (e.g., research papers, textbooks) into an interactive, oral conversation between two AI agents—Alpha and Beta. The system allows users to upload PDFs of academic content, generating dynamic discussions about the document’s material, which helps students and faculty engage with the content in a conversational format.
#
# ## **Key Concepts**
#
# ### **Large Language Models (LLMs):**
# These are **advanced AI models** capable of understanding and generating human-like text. Examples include **Llama 3, GPT-4, Gemini, and other AI tools** that process vast amounts of language data.

# %% [markdown]
# #🛠️ **Prerequisites**
# No need to install libraries or configure your environment manually! Everything is handled by the Google Colab Python Engine Backend. The setup will also create a Colab Runtime by enabling you to run code cell-by-cell without any typing or copying.
#
# 🐍 **Basic knowledge of Python** (optional)
# 📒 **Google Colab / Jupyter Notebook environment**
# 🌟 **The want to build an AI-powered chatbot!**
#
#
# You will need a GROQ API key which can be obtianited at([GROQ API](https://console.groq.com/keys))

# %% [markdown]
# #🤔 How It Works
# The chatbot relies on:
#
# LLMs (Large Language Models): Generate human respones to prompts
#
# *   LLMs (Large Language Models): Generate human respones to prompts
# *   PDF Extractor (PyPDF2): Extracts Text from PDF to use as refrecnce for podcast.

# %% [markdown]
# # Chatbot Flowchart Diagram
# ![Final Flowchart.png](data:image/png;base64,...)

# %% [markdown]
# # ⚙️ Running the Chatbot
# To set up and run the chatbot:
#
# Click on Runtime
# Select "Run All Cells"
# Have your GROQ API Key ready

# %% [markdown]
# # 📚 Why Are Libraries Important?
# Python libraries provide premade tools so that everything is not made from scratch. This project uses several specialized libraries to:
#
# Manage database operations.
# Extract Text from PDF.
# Create Web Based UI
# Create chat prompts and interactions.

# %% [markdown]
# # Table of Contents
# 1. [🧠 Step 1: Project Requirements](#scrollTo=OdwDNWZIgdFW)
# 2. [📦 Step 2: Project Overview](#scrollTo=EdtpQVktTjwM)
# 3. [🔧 Step 3: Workflow](#scrollTo=i3stzt6Uh4FJ)
# 4. [🗄️ Step 4: Installing Libaries](#scrollTo=CD8v2QW2iMBK)
# 5. [🔢 Step 5: Import neccesary libaries](#scrollTo=m65k39xPqwhl)
# 6. [🧹 Step 6: Enter GROQ API key](#scrollTo=viKU9r6bCxHZ)
# 7. [✂️ Step 7: Using two llama3 models for alpha and beta](#scrollTo=beTjX-bODAdP)
# 8. [💬 Step 8: Asking question to chatbot](#scrollTo=oibo1mG6DNCg)
# 9. [🤖 Step 9: Conversation between alpha and beta regarding csusb (aipodcast)](#scrollTo=BZeF15TpDTT-&line=1&uniqifier=1)

# %% [markdown]
# # **1. Project Requirements**
# Libraries Used
# The code requires the following Python libraries:
#
#
# * streamlit → For building the web-based UI
# *  speech_recognition → For voice-based interaction (optional)
# *   os → To handle environment variables
#
# *   pandas, numpy → For potential data processing
# *   langchain.chat_models → For initializing AI chat models
#
# *  langchain.schema → For structuring AI conversations
# *   PyPDF2 → For extracting text from uploaded PDF files
#
# *   time → To add natural pauses in the conversation

# %% [markdown]
# # **2. Project Overview**
#
# This document outlines the functional and non-functional requirements for the CSUSB Study Podcast Assistant, an AI-driven tool that allows students and faculty to engage with academic study materials in a conversational format. The primary objective of the system is to upload a research paper, chapter, or textbook section in PDF format, then generate an interactive conversation between two AI agents (Alpha and Beta) based on the content of the uploaded file. Users can query the system, receive accurate and prompt answers, all within a seamless, user-friendly interface.

# %% [markdown]
# # **3. Workflow**
#
# 1.User uploads a PDF file 📄
#
# 2.AI extracts text from the document 📖
#
# 3.Two AI agents (Alpha & Beta) generate a conversation 🗣️
#
# 4.The conversation is displayed in a podcast-style format 🎙️

# %% [markdown]
# # **4.  Installing Libraries**
#
# The CSUSB Study Podcast Assistant relies on several Python libraries to support data processing, natural language understanding, and integration with large language models. The following libraries must be installed in the runtime environment:

# %%
# !pip install pandas
# !pip install numpy
# !pip install langchain.core
# !pip install langchain_community
# !pip install langchain[groq]
# !pip install llama-index
# !pip install openai
# !pip install -U langchain-groq
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 437.6/437.6 kB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 360.3/360.3 kB 23.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.8/132.8 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 81.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 25.0
#     Uninstalling packaging-25.0:
#       Successfully uninstalled packaging-25.0
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 32.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 44.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# # **5. Import neccesary libaries**
#
# These libraries work together to enable key tasks such as PDF text extraction, AI-driven dialogue generation, and seamless interaction with language models. Installing and importing them at the beginning ensures the system is ready to process user input and generate meaningful conversations.

# %%
import os
import time
from langchain.chat_models import init_chat_model
from langchain.schema import SystemMessage, HumanMessage, AIMessage

# %% [markdown]
# # **6. Enter GROQ API key**
#
# To access and utilize the language model services provided by Groq, users must supply a valid API key. The system prompts the user to enter this key, which is then stored securely in an environment variable for use during runtime. This authentication step is required to initialize the AI agents and generate conversational responses based on the uploaded document.

# %%
apik = input("Please enter your GROQ API key: ").strip()
if not apik:
    raise ValueError("Error: API key cannot be empty.")
else:
    os.environ['GROQ_API_KEY'] = apik

# %% [markdown]
# # **7. Using two llama3 models for alpha and beta**
#
# To create a rich, dynamic, and insightful academic conversation, the CSUSB Study Podcast Assistant uses two separate AI agents—Alpha and Beta—each powered by distinct variants of the LLaMA 3 language model. This dual-model setup enhances the diversity of thought and tone in the generated dialogue.

# %%
chat_alpha = init_chat_model("llama3-8b-8192", model_provider="groq")  # Alpha's model
chat_beta = init_chat_model("llama3-70b-8192", model_provider="groq")  # Beta's model

messages = [SystemMessage(content="You are an AI assistant that will help.")]

# %% [markdown]
# # **8. Asking question to chatbot**
#
# The CSUSB Study Podcast Assistant allows users to directly engage with the AI agents by submitting custom questions related to the uploaded academic content. This feature enhances interactivity and provides tailored support for studying or clarification.

# %%
user_input = input("Ask the Chatbot a Question: ")

if user_input:
    prompt = f"User Query: {user_input}"

    response = chat_alpha.invoke([SystemMessage(content=prompt)])
    ai_response = response.content if response else "I do not know!"

    print(f"Alpha: {user_input}")
    print(f"Beta: {ai_response}")

# %% [markdown]
# # **9. Conversation between alpha and beta regarding csusb (aipodcast)**
#
# The **start_aipodcast()** function simulates a short, dynamic podcast-style dialogue between two AI agents, Alpha and Beta, centered around California State University, San Bernardino (CSUSB). This automated session highlights how the system can generate meaningful, topic-driven conversations using LLaMA 3 language models

# %%
def start_aipodcast():
    for _ in range(10):  # 10 questions session
        # Alpha asks a question about CSUSB
        question_prompt = "Generate a short, clear, and direct question (1-3 lines) about CSUSB's podcast, events, admissions, or campus life."

        messages.append(HumanMessage(content=question_prompt))
        question_response = chat_alpha.invoke(messages)
        question = question_response.content.strip() if question_response else "Could not generate a question."

        print(f"Alpha: {question}")
        time.sleep(1)

#Beta answers in 3-4 lines summary format
        beta_prompt = f"Provide a concise 3-4 line summary answering the following question: {question}"
        response = chat_beta.invoke([SystemMessage(content=beta_prompt)])
        ai_response = response.content.strip() if response else "I don't know"

        messages.append(AIMessage(content=ai_response))
        print(f"Beta: {ai_response}")
        print("-" * 50)
        time.sleep(1)

#Start AI Podcast
start_aipodcast()
